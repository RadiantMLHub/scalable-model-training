# %% [markdown]
# ### Import Required Libraries

# %%
import getpass
from pathlib import Path
import os, json
import itertools as it
import requests
from datetime import datetime
from tqdm import tqdm
from glob import glob

import shapely
from geopandas import GeoDataFrame
import rioxarray
import stackstac as ss
import numpy as np
import dask
from dask.distributed import Client as ds_client
import warnings

import pystac as ps
import pystac.utils as ps_utils
from pystac_client import Client as ps_client
from pystac import Item, Collection, Catalog
from pystac.extensions.label import LabelExtension, LabelRelType
from pystac.item_collection import ItemCollection

SAMPLE_SIZE = 5

# %% [markdown]
# ### Input MLHub API Key

# %%
MLHUB_API_KEY = getpass.getpass(prompt="MLHub API Key: ")
MLHUB_ROOT_URL = "https://api.radiant.earth/mlhub/v1"
# Out:
# MLHub API Key:  ································································

# %%
MLHUB_API_ROOT = "http://api.radiant.earth/mlhub/v1/collections"

# %%
# MLHUB_API_KEY

# %% [markdown]
# ### Authenticate Token with MLHub Session

# %%
class MLHubSession(requests.Session):
    def __init__(self, *args, api_key=None, **kwargs):
        super().__init__(*args, **kwargs)
        self.params.update({"key": api_key})

    def request(self, method, url, *args, **kwargs):
        url_prefix = MLHUB_ROOT_URL.rstrip("/") + "/"
        url = urljoin(url_prefix, url)
        return super().request(method, url, *args, **kwargs)

# %%
session = MLHubSession(api_key=MLHUB_API_KEY)

# %% [markdown]
# ### Create MLHub API Client

# %%
ps_api_client = ps_client.open(
    MLHUB_ROOT_URL, 
    parameters={"key": MLHUB_API_KEY}, 
    ignore_conformance=True
)

# %%
collections = ps_api_client.get_collections()

# %% [markdown]
# ### Fetch source and label collections

# %%
lcn_source_name, lcn_source = "ref_landcovernet_v1_source", None
lcn_labels_name, lcn_labels = "ref_landcovernet_v1_labels", None

# %%
for coll in collections:
    if coll.id == lcn_labels_name:
        lcn_labels = coll
    elif coll.id == lcn_source_name:
        lcn_source = coll

# %%
# lcn_labels.describe()

# %%
import numpy as np
np_rng = np.random.default_rng()

# %%
# lcn_label_items = lcn_labels.get_all_items_as_dict()

# %%
# %%time
lcn_label_items = lcn_labels.get_items()
lcn_source_items = lcn_source.get_items()
# Out:
# CPU times: user 14 µs, sys: 33 µs, total: 47 µs
# Wall time: 54.1 µs

# %%
lcn_labels.extent.spatial.bboxes[0]
# Out:
# [-15.937860500150009,
#  -31.68783755999348,
#  46.87392100826879,
#  31.339825523515234]

# %%
lcn_temporal_extent = lcn_labels.extent.temporal.intervals[0]
lcn_temporal_extent
# Out:
# [datetime.datetime(2018, 1, 1, 0, 0, tzinfo=tzutc()),
#  datetime.datetime(2018, 12, 31, 0, 0, tzinfo=tzutc())]

# %%
search_start = lcn_temporal_extent[0].strftime('%Y-%m-%d')
search_end = lcn_temporal_extent[1].strftime('%Y-%m-%d')

# %%
next(lcn_label_items).to_dict()
# Out:
# {'type': 'Feature',
#  'stac_version': '1.0.0',
#  'id': 'ref_landcovernet_v1_labels_38PKT_26',
#  'properties': {'labels': ['Artificial Bareground',
#    'Natural Bareground',
#    'Woody Vegetation',
#    '(Semi) Natural Vegetation'],
#   'datetime': '2018-07-01T00:00:00Z',
#   'label:type': 'raster',
#   'label:classes': [{'name': 'labels',
#     'classes': ['No Data',
#      'Water',
#      'Artificial Bareground',
#      'Natural Bareground',
#      'Permanent Snow/Ice',
#      'Woody Vegetation',
#      'Cultivated Vegetation',
#      '(Semi) Natural Vegetation']}],
#   'label:properties': ['labels'],
#   'label:description': 'Land Cover Type Classification'},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[42.725265852059046, 10.809570377835808],
#     [42.7250913255346, 10.832704943166526],
#     [42.748493655792764, 10.832876782947013],
#     [42.74866639065317, 10.809741842108567],
#     [42.725265852059046, 10.809570377835808]]]},
#  'links': [{'rel': 'collection',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_labels',
#    'type': 'application/json'},
#   {'rel': 'parent',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_labels',
#    'type': 'application/json'},
#   {'rel': <RelType.ROOT: 'root'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/',
#    'type': <MediaType.JSON: 'application/json'>,
#    'title': 'Radiant MLHub API'},
#   {'rel': 'self',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_labels/items/ref_landcovernet_v1_labels_38PKT_26',
#    'type': 'application/geo+json'},
#   {'rel': 'alternate',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_labels/items/ref_landcovernet_v1_labels_38PKT_26/tiles',
#    'type': 'application/json',
#    'title': 'tiles'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180101'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180106'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180111'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180116'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180121'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180126'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180131'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180205'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180210'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180215'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180220'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180225'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180302'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180307'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180312'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180317'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180322'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180327'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180401'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180406'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180411'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180416'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180421'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180426'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180501'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180506'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180511'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180516'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180521'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180526'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180531'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180605'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180610'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180615'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180625'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180630'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180705'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180710'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180715'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180720'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180725'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180730'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180804'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180809'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180814'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180819'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180824'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180829'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180903'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180908'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180913'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180918'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180923'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20180928'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20181003'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20181008'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20181013'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20181018'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20181023'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20181028'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20181102'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20181107'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20181112'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20181117'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20181122'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20181127'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20181202'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20181207'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20181212'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20181217'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20181222'},
#   {'rel': 'source',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38PKT_26_20181227'}],
#  'assets': {'labels': {'href': 'https://api.radiant.earth/mlhub/v1/download/gAAAAABh-ymBf7i9vdiWRQHqGOWndcr8x5fNbQ8Wux_y815oDtrJDNWVu8uykO_OC_K1JHAiUDHsWl6GwIQots0PMi_o7Pa0KjUNHBAP1PdPwL6XZYKe3iRzwnnBLHc5uOnsE6HlrIUHpqKeTc2D2qzgruWhFQrvGatplKMu0dk9KtYY0mn5YAzcaCtw6bzWxpPQJwHpae-oWQJcc8YSinxtKBbnqEjXWqr23Rue7r84ot6SOFDL8TgulikawSRshc6wbG-2RmQ0oIDEzG-DSL5fqJGdaEOadiY2HiX0b661tzgS59KL_e3Cj33Ur2zzwrh5FKK2RDrp',
#    'title': 'Land Cover'},
#   'source_dates': {'href': 'https://api.radiant.earth/mlhub/v1/download/gAAAAABh-ymBmfxiGjCWDsVT63lLxISgeNaVaxOzetRfAUhHBFZmXlhXijlOPiKuwO7Eo0KOfqExmBiUyDeJ3yrzcMjeoGxeNxzMSjxOlGZXVtDicErsVkuD5GPTiddmxmOxUbM1iKzqiYiaGg2VJpLaJlwGfwQlmvTEOGNhYyRHG1FTeVxSuiIXwKixgQTvUdXJm0quF8Sn-cX2FnQiiktErFPFPe5OjT6BQUtkQWz6LxYs-RlM27wTtiTgzIh3FWsyALIrEkJcqRq2bOaehoxsRt7BcSMbIXjS4Qd5LlJAoTDpe706aSV52P30IonxErppU0HVes8K',
#    'type': 'text/csv',
#    'title': 'Source Imagery Dates'},
#   'documentation': {'href': 'https://api.radiant.earth/mlhub/v1/download/gAAAAABh-ymBumzW6hR0Dg_pmAKZERAohyBqDptjt4Pep3zwDdWYA2scZoxmLplOqz9EeXLCszS3H9QFdcsJPyVa18HOoq7dxhtBkftvsad_tRXWsQzZpvPdog_yf6kOKmmOKIiA2dVgjzEbjTjEWgZgk_Z4xGWfThvW_Gyk6JAcV8ZhvoQIAAQnE3dLcwe0C5fR3_JrnbLGIQd9qP_Fm1dR-TnePFcF9NDBCXO-y0A1RnmWjoEchn8lzYfbZfgSIGgUm1vTWY9bKONFdQmnrjFH0uOec1XaOA==',
#    'type': 'application/pdf',
#    'title': 'Dataset Documentation'}},
#  'bbox': [42.7250913255346,
#   10.809570377835808,
#   42.74866639065317,
#   10.832876782947013],
#  'stac_extensions': ['https://stac-extensions.github.io/label/v1.0.0/schema.json'],
#  'collection': 'ref_landcovernet_v1_labels'}

# %%
i=0
while i < 5:
    first_label = next(lcn_label_items)
    first_source = next(lcn_source_items)
    print(first_label.id, first_source.id)
    i+=1
# Out:
# ref_landcovernet_v1_labels_38PKT_29 ref_landcovernet_v1_source_38NPP_29_20181231
# ref_landcovernet_v1_labels_38PKT_28 ref_landcovernet_v1_source_38NPP_28_20181231
# ref_landcovernet_v1_labels_38PKT_27 ref_landcovernet_v1_source_38NPP_27_20181231
# ref_landcovernet_v1_labels_38PKT_26 ref_landcovernet_v1_source_38NPP_26_20181231
# ref_landcovernet_v1_labels_38PKT_25 ref_landcovernet_v1_source_38NPP_25_20181231

# %% [markdown]
# #### It is estimated this will take over 30 minutes for all source items

# %%
# %%time
# lcn_source_item_list = list(lcn_source_items)

# %% [markdown]
# #### Conversion from labels generator to list takes 24 seconds

# %%
# %%time
lcn_label_item_list = list(lcn_label_items)
# Out:
# CPU times: user 1.33 s, sys: 94.7 ms, total: 1.42 s
# Wall time: 20.9 s

# %%
# %%time
sample_label_items = np_rng.choice(a=lcn_label_item_list, size=SAMPLE_SIZE)
# Out:
# CPU times: user 5 ms, sys: 3.76 ms, total: 8.76 ms
# Wall time: 13 ms

# %%
# sample_label_items[0].get_links(rel=LabelRelType.SOURCE)[0:10]

# %%
sample_label_items
# Out:
# array([<Item id=ref_landcovernet_v1_labels_29PNM_21>,
#        <Item id=ref_landcovernet_v1_labels_33PWQ_14>,
#        <Item id=ref_landcovernet_v1_labels_37PCM_04>,
#        <Item id=ref_landcovernet_v1_labels_32PQQ_09>,
#        <Item id=ref_landcovernet_v1_labels_34MBC_20>], dtype=object)

# %%
for label_item in sample_label_items[:1]:
    source_item_links = label_item.get_links(rel=LabelRelType.SOURCE)
    print(source_item_links)
# Out:
# [<Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180105>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180110>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180115>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180120>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180125>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180130>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180204>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180209>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180214>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180219>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180224>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180301>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180306>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180311>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180316>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180321>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180326>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180331>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180405>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180410>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180415>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180420>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180425>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180430>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180505>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180510>, <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/it ...

# %% [markdown]
# #### .get_item() on n items will be O(n^2) as it walks the entire collection for each item ID

# %%
# %%time
lcn_source.get_item(os.path.split(source_item_links[0].target)[-1], recursive=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/pystac/catalog.py in get_item(self, id, recursive)
#     412         """
#     413         if not recursive:
# --> 414             return next((i for i in self.get_items() if i.id == id), None)
#     415         else:
#     416             for root, _, _ in self.walk():
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/pystac/catalog.py in <genexpr>(.0)
#     412         """
#     413         if not recursive:
# --> 414             return next((i for i in self.get_items() if i.id == id), None)
#     415         else:
#     416             for root, _, _ in self.walk():
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/pystac_client/collection_client.py in get_items(self)
#      25         if link is not None:
#      26             search = ItemSearch(link.href, method='GET', stac_io=self.get_root()._stac_io)
# ---> 27             yield from search.get_items()
#      28         else:
#      29             yield from super().get_items()
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/pystac_client/item_search.py in get_items(self)
#     445         """
#     446         nitems = 0
# --> 447         for item_collection in self.get_item_collections():
#     448             for item in item_collection:
#     449                 yield item
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/pystac_client/item_search.py in get_item_collections(self)
#     433             Iterable[Item] : pystac_client.ItemCollection
#     434         """
# --> 435         for page in self._stac_io.get_pages(self.url, self.method, self.get_parameters()):
#     436             yield ItemCollection.from_dict(page, preserve_dict=False, root=self.client)
#     437
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/pystac_client/stac_api_io.py in get_pages(self, url, method, parameters)
#     213         while next_link:
#     214             link = Link.from_dict(next_link)
# --> 215             page = self.read_json(link, parameters=parameters)
#     216             yield page
#     217
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/pystac/stac_io.py in read_json(self, source, *args, **kwargs)
#     195             given source.
#     196         """
# --> 197         txt = self.read_text(source, *args, **kwargs)
#     198         return self.json_loads(txt)
#     199
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/pystac_client/stac_api_io.py in read_text(self, source, parameters, *args, **kwargs)
#      98                 # parameters are already in the link href
#      99                 parameters = {}
# --> 100             return self.request(href, *args, method=method, headers=headers, parameters=parameters)
#     101
#     102     def request(self,
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/pystac_client/stac_api_io.py in request(self, href, method, headers, parameters)
#     132                 msg += f" Payload: {json.dumps(request.json)}"
#     133             logger.debug(msg)
# --> 134             resp = self.session.send(prepped)
#     135             if resp.status_code != 200:
#     136                 raise APIError(resp.text)
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     675             # Redirect resolving generator.
#     676             gen = self.resolve_redirects(r, request, **kwargs)
# --> 677             history = [resp for resp in gen]
#     678         else:
#     679             history = []
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/requests/sessions.py in <listcomp>(.0)
#     675             # Redirect resolving generator.
#     676             gen = self.resolve_redirects(r, request, **kwargs)
# --> 677             history = [resp for resp in gen]
#     678         else:
#     679             history = []
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     235             else:
#     236
# --> 237                 resp = self.send(
#     238                     req,
#     239                     stream=stream,
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/http/client.py in getresponse(self)
#    1369         try:
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#    1373                 self.close()
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
source_item_links[0]
# Out:
# <Link rel=source target=http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_04_20180105>

# %%
source_item_links[0].resolve_stac_object(stac_io=ps_client._stac_io).target
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/87/c2vwc00s3rq1xw26bz5j25rh0000gn/T/ipykernel_1080/3495623330.py in <module>
# ----> 1 source_item_links[0].resolve_stac_object(stac_io=ps_client._stac_io).target
#
# TypeError: resolve_stac_object() got an unexpected keyword argument 'stac_io'

# %%
# lcn_source.get_item('ref_landcovernet_v1_source_35KNT_04_20180105')

# %%
# %%time
sample_source_items = []
for label in sample_label_items:
    source_item_id = label.id.replace('_labels_', '_source_')
    if source_item_id:
        sample_source_items.append(lcn_source_items.get_item(source_item_id + '_20180902'))
    else:
        print(f'Could not find source items for {label.id}')
# Out:
# ref_landcovernet_v1_labels_34NCG_16 ref_landcovernet_v1_source_34NCG_16
# ref_landcovernet_v1_labels_35NLA_16 ref_landcovernet_v1_source_35NLA_16
# ref_landcovernet_v1_labels_31PGR_20 ref_landcovernet_v1_source_31PGR_20
# ref_landcovernet_v1_labels_32PLS_28 ref_landcovernet_v1_source_32PLS_28
# ref_landcovernet_v1_labels_29PNM_27 ref_landcovernet_v1_source_29PNM_27
# ref_landcovernet_v1_labels_33MZM_14 ref_landcovernet_v1_source_33MZM_14
# ref_landcovernet_v1_labels_37NFD_26 ref_landcovernet_v1_source_37NFD_26
# ref_landcovernet_v1_labels_33PUQ_16 ref_landcovernet_v1_source_33PUQ_16
# ref_landcovernet_v1_labels_35JKL_24 ref_landcovernet_v1_source_35JKL_24
# ref_landcovernet_v1_labels_38PKQ_26 ref_landcovernet_v1_source_38PKQ_26
# CPU times: user 1.17 ms, sys: 482 µs, total: 1.65 ms
# Wall time: 3.86 ms

# %%
sample_source_ids = [label.id.replace('_labels_', '_source_') for label in sample_label_items]
sample_source_ids
# Out:
# ['ref_landcovernet_v1_source_34NCG_16',
#  'ref_landcovernet_v1_source_35NLA_16',
#  'ref_landcovernet_v1_source_31PGR_20',
#  'ref_landcovernet_v1_source_32PLS_28',
#  'ref_landcovernet_v1_source_29PNM_27',
#  'ref_landcovernet_v1_source_33MZM_14',
#  'ref_landcovernet_v1_source_37NFD_26',
#  'ref_landcovernet_v1_source_33PUQ_16',
#  'ref_landcovernet_v1_source_35JKL_24',
#  'ref_landcovernet_v1_source_38PKQ_26']

# %%
sample_source_items = []

# %%
lcn_source_items
# Out:
# <generator object CollectionClient.get_items at 0x175a8e270>

# %%
blob_url = 'https://radiantmlhub.blob.core.windows.net/stac/landcovernet-v1/catalog.json'

# %%
# blob_cat = ps.read_file(blob_url, stac_io = ps_api_client._stac_io)

# %%
# %%time
# for source_item in lcn_source_items:
#     if source_item.id in sample_source_ids:
#         sample_source_items.append(source_item)

# %%
lcn_labels.id
# Out:
# 'ref_landcovernet_v1_labels'

# %%
lcn_labels_collection = Collection(
    id = lcn_labels.id,
    description = lcn_labels.description,
    extent = lcn_labels.extent
)

# %%
lcn_labels_collection.add_items(lcn_label_items)

# %%
lcn_source_collection = Collection(
    id = lcn_source.id,
    description = lcn_source.description,
    extent = lcn_source.extent
)

# %%
lcn_source_collection.add_items(lcn_source_items)

# %%
len(lcn_source_collection.to_dict()['links'])
# Out:
# 102

# %%
lcn_source_collection.to_dict()
# Out:
# {'type': 'Collection',
#  'id': 'ref_landcovernet_v1_source',
#  'stac_version': '1.0.0',
#  'description': 'LandCoverNet Source Imagery',
#  'links': [{'rel': <RelType.ROOT: 'root'>,
#    'href': None,
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_29_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_28_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_27_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_26_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_25_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_24_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_23_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_22_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_21_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_20_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_19_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_18_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_17_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_16_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_15_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_14_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_13_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_12_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_11_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_10_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_09_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_08_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_07_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_06_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_05_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_04_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_03_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_02_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_01_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_00_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_29_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_28_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_27_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_26_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_25_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_24_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_23_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_22_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_21_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_20_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_19_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_18_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_17_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_16_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_15_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_14_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_13_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_12_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_11_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_10_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_09_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_08_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_07_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_06_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_05_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_04_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_03_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_02_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_01_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PZC_00_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_29_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_28_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_27_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_26_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_25_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_24_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_23_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_22_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_21_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_20_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_19_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_18_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_17_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_16_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_15_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_14_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_13_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_12_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_11_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_10_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_09_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_08_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_07_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_06_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_05_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_04_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_03_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_02_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_01_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_36PYV_00_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_29_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_28_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_27_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_26_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_25_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_24_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_23_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_22_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_21_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.ITEM: 'item'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_35KNT_20_20181231',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.PARENT: 'parent'>,
#    'href': None,
#    'type': <MediaType.JSON: 'application/json'>}],
#  'stac_extensions': [],
#  'extent': {'spatial': {'bbox': [[-15.937860500150009,
#      -31.68783755999348,
#      46.87392100826879,
#      31.339825523515234]]},
#   'temporal': {'interval': [['2018-01-01T00:00:00Z',
#      '2018-12-31T00:00:00Z']]}},
#  'license': 'proprietary'}

# %% [markdown]
# ### Create template Catalog, add Collections

# %%
lcn_catalog = Catalog(
    id="landcovernet_v1",
    description="LandCoverNet",
    href="."
)
lcn_catalog._stac_io = ps_api_client._stac_io

# %%
lcn_catalog.add_children([lcn_source, lcn_labels])

# %%
lcn_catalog.to_dict()
# Out:
# {'type': 'Catalog',
#  'id': 'landcovernet_v1',
#  'stac_version': '1.0.0',
#  'description': 'LandCoverNet',
#  'links': [{'rel': <RelType.ROOT: 'root'>,
#    'href': '/Users/kendallsmith/scalable-model-training',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.SELF: 'self'>,
#    'href': '/Users/kendallsmith/scalable-model-training',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.CHILD: 'child'>,
#    'href': '/Users/kendallsmith/ref_landcovernet_v1_source/collection.json',
#    'type': <MediaType.JSON: 'application/json'>},
#   {'rel': <RelType.CHILD: 'child'>,
#    'href': '/Users/kendallsmith/ref_landcovernet_v1_labels/collection.json',
#    'type': <MediaType.JSON: 'application/json'>}],
#  'stac_extensions': []}

# %%
for collection_link in lcn_catalog.get_child_links():
    print(collection_link)
# Out:
# <Link rel=child target=<CollectionClient id=ref_landcovernet_v1_source>>
# <Link rel=child target=<CollectionClient id=ref_landcovernet_v1_labels>>

# %%
with open('labels_collection.json', 'w') as out_file:
    json.dump(lcn_catalog.get_child('ref_landcovernet_v1_labels').to_dict(), out_file)

# %%
with open('source_collection.json', 'w') as out_file:
    json.dump(lcn_catalog.get_child('ref_landcovernet_v1_source').to_dict(), out_file)

# %%
# %%time
lcn_catalog.get_child('ref_landcovernet_v1_labels').get_item('ref_landcovernet_v1_labels_38NPP_22').to_dict()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed eval> in <module>
#
# NameError: name 'lcn_catalog' is not defined

# %%
next(next(lcn_catalog.get_children()).get_items()).to_dict()
# Out:
# {'type': 'Feature',
#  'stac_version': '1.0.0',
#  'id': 'ref_landcovernet_v1_source_38NPP_29_20181231',
#  'properties': {'gsd': 10,
#   'datetime': '2018-12-31T00:00:00Z',
#   'eo:bands': [{'name': 'B01',
#     'common_name': 'Coastal Aerosol',
#     'description': 'Coastal Aerosol'},
#    {'name': 'B02', 'common_name': 'Blue', 'description': 'Blue'},
#    {'name': 'B03', 'common_name': 'Green', 'description': 'Green'},
#    {'name': 'B04', 'common_name': 'Red', 'description': 'Red'},
#    {'name': 'B05',
#     'common_name': 'Vegetation Red Edge',
#     'description': 'Vegetation Red Edge (704.1nm)'},
#    {'name': 'B06',
#     'common_name': 'Vegetation Red Edge',
#     'description': 'Vegetation Red Edge (740.1nm)'},
#    {'name': 'B07',
#     'common_name': 'Vegetation Red Edge',
#     'description': 'Vegetation Red Edge (782.8nm)'},
#    {'name': 'B08', 'common_name': 'NIR', 'description': 'NIR'},
#    {'name': 'B8A', 'common_name': 'Narrow NIR', 'description': 'Narrow NIR'},
#    {'name': 'B09',
#     'common_name': 'Water Vapour',
#     'description': 'Water Vapour'},
#    {'name': 'B10',
#     'common_name': 'SWIR - Cirrus',
#     'description': 'SWIR - Cirrus'},
#    {'name': 'B11', 'common_name': 'SWIR', 'description': 'SWIR (1613.7nm)'},
#    {'name': 'B12', 'common_name': 'SWIR', 'description': 'SWIR (2202.4nm)'},
#    {'name': 'CLD', 'common_name': 'Cloud Mask', 'description': 'Cloud Mask'},
#    {'name': 'SCL',
#     'common_name': 'Scene Classification Layer',
#     'description': 'Scene Classification Layer'}],
#   'platform': 'Sentinel-2',
#   'instruments': ['MSI'],
#   'constellation': 'Sentinel-2'},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[46.36242095411817, 7.893776669006948],
#     [46.36249690667989, 7.916926803469829],
#     [46.38571616583332, 7.916850317304118],
#     [46.385638919912125, 7.893700409244037],
#     [46.36242095411817, 7.893776669006948]]]},
#  'links': [{'rel': 'collection',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source',
#    'type': 'application/json'},
#   {'rel': 'parent',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source',
#    'type': 'application/json'},
#   {'rel': <RelType.ROOT: 'root'>,
#    'href': 'http://api.radiant.earth/mlhub/v1/',
#    'type': <MediaType.JSON: 'application/json'>,
#    'title': 'Radiant MLHub API'},
#   {'rel': 'self',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_29_20181231',
#    'type': 'application/geo+json'},
#   {'rel': 'alternate',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_29_20181231/tiles',
#    'type': 'application/json',
#    'title': 'tiles'}],
#  'assets': {'B01': {'href': 'https://api.radiant.earth/mlhub/v1/download/gAAAAABh-ECsR4t6XI9b6n7qL3AfMJ07sKVW3ppyOgNeXMGHR_tQ9ZX0YneCg8RpPFLNNhUcCvScNyIHkdQulYplxMU4dQIPz9oJkyPeT3J66hwMk9AV4HZ3YLxhk8L2Tsr46RKrnUwDFqbAi7Vxy7rHBgaMRxVBeqnX5Lmkidpi58zMnd1yvRhCXRp2-xCb6HMCQVYj5Qe4ZubCqMi2JrX3U_JE6VDoHm_mLNeF5qZzYAbA2NcbitAaCB_4kDb4odvho-VpYq7lVbf3qQiMEceTQxmWud46ifgJJvft8yBmRabRYnE033DjcynhK7QabPPUxeU3RKdIbC8fJ3gmsr6iUt5SJLRusA==',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': '38NPP_29_20181231_B01_10m',
#    'eo:bands': [{'name': 'B01',
#      'common_name': 'Coastal Aerosol',
#      'description': 'Coastal Aerosol'}]},
#   'B02': {'href': 'https://api.radiant.earth/mlhub/v1/download/gAAAAABh-ECsUL6ywNllqTtndcItZc4pz9U1Vb-wwgZNzHKwMaLN236LAI8TY0_--FhCSNS2p8PWBRaPgDRHjmXNUV71zLk5EjoaSIiEK-v2finSOzW0xmDdEO04M1Rd-ut-bODLL5jU40ltLJvlJlR6VxIXMdJyKs6yBvYovQXCJDGxyfZMZf4cTNH8aUa3OcqYb5g5yG8zpVaICeojiG-vZJ7gWK3OImMj4D7lNyh6OoXZUW1y-dZhi2KSCFv5uKiBAbquqKXnfyqwpQMhYpnD_zGRul3BMxpmm8ydj9le4mCmM5vZF82TObS9q14vKv1r7H0zmyZRfzfwo1rMbM49nBbpJGeGFg==',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': '38NPP_29_20181231_
{'href': 'https://api.radiant.earth/mlhub/v1/download/gAAAAABh-ECsQDvKH2jOnE-GObKhGS0XpMOOpOcNYtvKLUmCHPCxvysqNMYR2rgXMnKvC2hfK2XQANxyccUNPYy5CEI_qbT9zKTgHl6fDOKpXxGwjBnqYXWbe-VY39oTcofY4SoahGS1Pi5vQfd_jUUPje9FKtK3SK7LUalXikEqpAHsDDx4FJ376B5HVHJR1vB9DtXEJIozpAsljrWFY4qcxrV8XcBy8SCGmvpFlz6oElrvYST2QDqb724BX8I71rxC1SzQ7vKeXrWGcdOwVj2d4l93WFffmzdTw0eVxsDSvRnaCGcgDD4N8OjohP6VDvZUSA2CHqn-JlPyrJXohLoNGVWdsvcxfA==',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': '38NPP_29_20181231_SCL_10m',
#    'eo:bands': [{'name': 'SCL',
#      'common_name': 'Scene Classification Layer',
#      'description': 'Scene Classification Layer'}]}},
#  'bbox': [46.36242095411817,
#   7.893700409244037,
#   46.38571616583332,
#   7.916926803469829],
#  'stac_extensions': ['https://stac-extensions.github.io/eo/v1.0.0/schema.json'],
#  'collection': 'ref_landcovernet_v1_source'}

# %% [markdown]
# ### Make Catalog child Links relative to Catalog root

# %%
for collection_link in lcn_catalog.get_child_links():
    # Get the collection link relative to the original catalog at the broken Azure blob URL
    collection_link.target = ps_utils.make_relative_href(
        collection_link.get_target_str(),
        start_href=MLHUB_API_ROOT,
        start_is_dir=True
    )

# %%
for collection_link in lcn_catalog.get_child_links():
    print(collection_link.get_target_str())
# Out:
# /Users/kendallsmith/ref_landcovernet_v1_source/collection.json
# /Users/kendallsmith/ref_landcovernet_v1_labels/collection.json

# %% [markdown]
# ### Make Collections Links relative to Catalog root

# %%
# %%time
for collection in lcn_catalog.get_collections():
    print(f'Updating relative paths for {collection.id}')
    
    for item_link in collection.get_item_links():
        # First, get the Item's URL relative to the original catalog at the broken Azure URL
        relative_to_root = ps_utils.make_relative_href(
            item_link.get_target_str(),
            start_href=MLHUB_API_ROOT,
            start_is_dir=True
        )
        # print(relative_to_root)
        
        # Next, get the absolute local path and then the path relative to the collection
        absolute_path = ps_utils.make_absolute_href(
            relative_to_root,
            start_href=collection.get_root_link().href
        )
        # print(absolute_path)
        
        relative_to_collection = ps_utils.make_relative_href(
            absolute_path,
            start_href=collection.get_self_href()
        )
        item_link.target = relative_to_collection
# Out:
# Updating relative paths for ref_landcovernet_v1_source
# Updating relative paths for ref_landcovernet_v1_labels

# %%
# destination_catalog_dir = Path(os.getcwd()) / "output"
destination_catalog_dir = os.path.join(os.getcwd(), 'output')

# %% [markdown]
# ### Make Item Links relative to Collections

# %%
# %%time
for current_catalog, sub_catalogs, items in lcn_catalog.walk():
    for item in items:
        # WARNING: NOT IDEMPOTENT
        # Prefix the Item ID with the Collection ID
        item.id = current_catalog.id + "-" + item.id
        item.set_root(lcn_catalog)
        item.set_collection(current_catalog)

        # Fix the asset HREFs
        for asset in item.assets.values():
            relative_to_root = ps_utils.make_relative_href(
                asset.href,
                start_href=MLHUB_API_ROOT,
                start_is_dir=True
            )
            asset.href = ps_utils.make_absolute_href(
                relative_to_root,
                start_href=destination_catalog_dir,
                start_is_dir=True
            )
        
        # Fix the source links, if present
        for source_link in item.get_links(rel=LabelRelType.SOURCE):
            # First, get the path relative to the old root
            relative_to_root = ps_utils.make_relative_href(
                source_link.get_target_str(),
                start_href=MLHUB_API_ROOT,
                start_is_dir=True
            )
            # Next get the absolute local path and then the path relative to THIS ITEM
            absolute_path = ps_utils.make_absolute_href(
                relative_to_root,
                start_href=item.get_root_link().href
            )
            source_link.target = ps_utils.make_relative_href(
                absolute_path,
                start_href=item.get_self_href()
            )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/87/c2vwc00s3rq1xw26bz5j25rh0000gn/T/ipykernel_76315/558365699.py in <module>
#       1 for current_catalog, sub_catalogs, items in lcn_catalog.walk():
# ----> 2     for item in items:
#       3         # WARNING: NOT IDEMPOTENT
#       4         # Prefix the Item ID with the Collection ID
#       5         item.id = current_catalog.id + "-" + item.id
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/pystac_client/collection_client.py in get_items(self)
#      25         if link is not None:
#      26             search = ItemSearch(link.href, method='GET', stac_io=self.get_root()._stac_io)
# ---> 27             yield from search.get_items()
#      28         else:
#      29             yield from super().get_items()
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/pystac_client/item_search.py in get_items(self)
#     445         """
#     446         nitems = 0
# --> 447         for item_collection in self.get_item_collections():
#     448             for item in item_collection:
#     449                 yield item
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/pystac_client/item_search.py in get_item_collections(self)
#     433             Iterable[Item] : pystac_client.ItemCollection
#     434         """
# --> 435         for page in self._stac_io.get_pages(self.url, self.method, self.get_parameters()):
#     436             yield ItemCollection.from_dict(page, preserve_dict=False, root=self.client)
#     437
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/pystac_client/stac_api_io.py in get_pages(self, url, method, parameters)
#     213         while next_link:
#     214             link = Link.from_dict(next_link)
# --> 215             page = self.read_json(link, parameters=parameters)
#     216             yield page
#     217
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/pystac/stac_io.py in read_json(self, source, *args, **kwargs)
#     195             given source.
#     196         """
# --> 197         txt = self.read_text(source, *args, **kwargs)
#     198         return self.json_loads(txt)
#     199
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/pystac_client/stac_api_io.py in read_text(self, source, parameters, *args, **kwargs)
#      98                 # parameters are already in the link href
#      99                 parameters = {}
# --> 100             return self.request(href, *args, method=method, headers=headers, parameters=parameters)
#     101
#     102     def request(self,
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/pystac_client/stac_api_io.py in request(self, href, method, headers, parameters)
#     132                 msg += f" Payload: {json.dumps(request.json)}"
#     133             logger.debug(msg)
# --> 134             resp = self.session.send(prepped)
#     135             if resp.status_code != 200:
#     136                 raise APIError(resp.text)
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     675             # Redirect resolving generator.
#     676             gen = self.resolve_redirects(r, request, **kwargs)
# --> 677             history = [resp for resp in gen]
#     678         else:
#     679             history = []
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/requests/sessions.py in <listcomp>(.0)
#     675             # Redirect resolving generator.
#     676             gen = self.resolve_redirects(r, request, **kwargs)
# --> 677             history = [resp for resp in gen]
#     678         else:
#     679             history = []
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     235             else:
#     236
# --> 237                 resp = self.send(
#     238                     req,
#     239                     stream=stream,
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     695
#     696         if not stream:
# --> 697             r.content
#     698
#     699         return r
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/requests/models.py in content(self)
#     834                 self._content = None
#     835             else:
# --> 836                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     837
#     838         self._content_consumed = True
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/requests/models.py in generate()
#     756             if hasattr(self.raw, 'stream'):
#     757                 try:
# --> 758                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     759                         yield chunk
#     760                 except ProtocolError as e:
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     574         else:
#     575             while not is_fp_closed(self._fp):
# --> 576                 data = self.read(amt=amt, decode_content=decode_content)
#     577
#     578                 if data:
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/http/client.py in read(self, amt)
#     460             # Amount is given, implement using readinto
#     461             b = bytearray(amt)
# --> 462             n = self.readinto(b)
#     463             return memoryview(b)[:n].tobytes()
#     464         else:
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/http/client.py in readinto(self, b)
#     504         # connection, and the user is reading more bytes than will be provided
#     505         # (for example, reading in 1k chunks)
# --> 506         n = self.fp.readinto(b)
#     507         if not n and b:
#     508             # Ideally, we would raise IncompleteRead if the content-length
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
for current_catalog, sub_catalogs, items in lcn_catalog.walk():
    for catalog in sub_catalogs:
        print(catalog.get_self_href())
# Out:
# http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source
# http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_labels

# %% [markdown]
# ### Instantiate Dask Client

# %%
client = ds_client()
client.run(lambda: warnings.filterwarnings("ignore", "Creating an ndarray from ragged"))
client
# Out:
# /Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/node.py:160: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 55635 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:55636' processes=4 threads=8, memory=16.00 GiB>

# %% [markdown]
# #### Load Label Items from raw JSON collection

# %%
item_files = glob('/Users/kendallsmith/scalable-model-training/landcovernet-v1/landcovernet_v1_labels/**/*.json', recursive=True)

# %%
item_files = [file for file in item_files if not file.__contains__('collection.json') and not file.__contains__('catalog.json')]

# %%
item_files[0:5]
# Out:
# ['/Users/kendallsmith/scalable-model-training/landcovernet-v1/landcovernet_v1_labels/landcovernet_v1_labels_38NPP_05/landcovernet_v1_labels_38NPP_05.json',
#  '/Users/kendallsmith/scalable-model-training/landcovernet-v1/landcovernet_v1_labels/landcovernet_v1_labels_30PWT_01/landcovernet_v1_labels_30PWT_01.json',
#  '/Users/kendallsmith/scalable-model-training/landcovernet-v1/landcovernet_v1_labels/landcovernet_v1_labels_35MNT_01/landcovernet_v1_labels_35MNT_01.json',
#  '/Users/kendallsmith/scalable-model-training/landcovernet-v1/landcovernet_v1_labels/landcovernet_v1_labels_32PPA_05/landcovernet_v1_labels_32PPA_05.json',
#  '/Users/kendallsmith/scalable-model-training/landcovernet-v1/landcovernet_v1_labels/landcovernet_v1_labels_31PGS_02/landcovernet_v1_labels_31PGS_02.json']

# %%
len(item_files)
# Out:
# 1980

# %%
features = []
last_idx = 0

# %%
# %%time
for idx, item_filepath in enumerate(item_files):
    
    with open(item_filepath, 'r') as in_file:
        label_data = json.load(in_file)
        
    label_feature = {
        "id": str(last_idx),
        "type": label_data['type'],
        "properties": {
            "name": os.path.split(item_filepath)[-1]
        },
        "geometry": label_data['geometry'],
        "bbox": label_data['bbox'],
        
    }
    
    features.append(label_feature)
    last_idx = last_idx + idx + 1
# Out:
# CPU times: user 157 ms, sys: 67.2 ms, total: 224 ms
# Wall time: 572 ms

# %%
features[0:5]
# Out:
# [{'id': '0',
#   'type': 'Feature',
#   'properties': {'name': 'landcovernet_v1_labels_38NPP_05.json'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[46.22372650315114, 7.637727360104802],
#      [46.223792488589126, 7.66087904636043],
#      [46.24699893998356, 7.660812489646023],
#      [46.24693170406418, 7.637661006840825],
#      [46.22372650315114, 7.637727360104802]]]},
#   'bbox': [46.22372650315114,
#    7.637661006840825,
#    46.24699893998356,
#    7.66087904636043]},
#  {'id': '1',
#   'type': 'Feature',
#   'properties': {'name': 'landcovernet_v1_labels_30PWT_01.json'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-2.110483678027241, 11.084611605508577],
#      [-2.110413637624084, 11.107761306888117],
#      [-2.086974187855211, 11.107691143828443],
#      [-2.08704607311562, 11.08454159225002],
#      [-2.110483678027241, 11.084611605508577]]]},
#   'bbox': [-2.110483678027241,
#    11.08454159225002,
#    -2.086974187855211,
#    11.107761306888117]},
#  {'id': '3',
#   'type': 'Feature',
#   'properties': {'name': 'landcovernet_v1_labels_35MNT_01.json'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[27.334854827734194, -2.702727971880426],
#      [27.334848507965514, -2.6795677597129015],
#      [27.357879171457583, -2.679561214245505],
#      [27.357885925873976, -2.7027213697585264],
#      [27.334854827734194, -2.702727971880426]]]},
#   'bbox': [27.334848507965514,
#    -2.702727971880426,
#    27.357885925873976,
#    -2.679561214245505]},
#  {'id': '6',
#   'type': 'Feature',
#   'properties': {'name': 'landcovernet_v1_labels_32PPA_05.json'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[10.26125498910584, 14.040146360424616],
#      [10.26138171421494, 14.063288132300281],
#      [10.285088049606442, 14.063163150817273],
#      [10.28495894441559, 14.040021592763049],
#      [10.26125498910584, 14.040146360424616]]]},
#   'bbox': [10.26125498910584,
#    14.040021592763049,
#    10.285088049606442,
#    14.063288132300281]},
#  {'id': '10',
#   'type': 'Feature',
#   'properties': {'name': 'landcovernet_v1_labels_31PGS_02.json'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[5.2619714677765, 15.257595712040002],
#      [5.262219305127048, 15.28072256514514],
#      [5.2860440935106245, 15.28048052087582],
#      [5.285793651548741, 15.257354051354916],
#      [5.2619714677765, 15.257595712040002]]]},
#   'bbox': [5.2619714677765,
#    15.257354051354916,
#    5.2860440935106245,
#    15.28072256514514]}]

# %%
feature_collection = {
    "type": "FeatureCollection",
    "features": features,
    "bbox": lcn_labels.extent.spatial.bboxes[0]
}

# %%
lcn_gdf = GeoDataFrame.from_features(feature_collection)

# %%
lcn_gdf.head()
# Out:
#                                             geometry  \
# 0  POLYGON ((46.22373 7.63773, 46.22379 7.66088, ...
# 1  POLYGON ((-2.11048 11.08461, -2.11041 11.10776...
# 2  POLYGON ((27.33485 -2.70273, 27.33485 -2.67957...
# 3  POLYGON ((10.26125 14.04015, 10.26138 14.06329...
# 4  POLYGON ((5.26197 15.25760, 5.26222 15.28072, ...
#
#                                    name
# 0  landcovernet_v1_labels_38NPP_05.json
# 1  landcovernet_v1_labels_30PWT_01.json
# 2  landcovernet_v1_labels_35MNT_01.json
# 3  landcovernet_v1_labels_32PPA_05.json
# 4  landcovernet_v1_labels_31PGS_02.json

# %%
json.dump(shapely.geometry.mapping(lcn_gdf.unary_union.convex_hull), open('unary_geometry.json', 'w'))

# %%
json.dump(shapely.geometry.mapping(lcn_gdf.iloc[0:20].unary_union), open('unary_geometry2.json', 'w'))

# %%
os.getcwd()
# Out:
# '/Users/kendallsmith/scalable-model-training'

# %%
# !pip install dask_geopandas

# %%
import dask_geopandas

# %%
NPARTITIONS = 1980
lcn_dgdf = dask_geopandas.from_geopandas(lcn_gdf, npartitions=NPARTITIONS, sort=False)

# %%
def query(labels):
    """
    Find STAC items for points in the `points` DataFrame

    Parameters
    ----------
    points : geopandas.GeoDataFrame
        A GeoDataFrame

    Returns
    -------
    geopandas.GeoDataFrame
        A new geopandas.GeoDataFrame with a `stac_item` column containing the STAC
        item that covers each point.
    """
    intersects = shapely.geometry.mapping(labels.unary_union.convex_hull)

    # search_start = "2018-01-01"
    # search_end = "2019-12-31"
    catalog = pystac_client.Client.open(MLHUB_ROOT_URL)

    # The time frame in which we search for non-cloudy imagery
    search = catalog.search(
        collections=[lcn_labels_name],
        intersects=intersects,
        datetime=[search_start, search_end],
        query={}, # "eo:cloud_cover": {"lt": 10}
        limit=100,
    )
    ic = search.get_all_items_as_dict()

    features = ic["features"]
    features_d = {item["id"]: item for item in features}

    data = {
        #"eo:cloud_cover": [],
        "geometry": [],
    }

    index = []

    for item in features:
        #data["eo:cloud_cover"].append(item["properties"]["eo:cloud_cover"])
        data["geometry"].append(shapely.geometry.shape(item["geometry"]))
        index.append(item["id"])

    items = geopandas.GeoDataFrame(data, index=index, geometry="geometry")#.sort_values("eo:cloud_cover")
    point_list = points.geometry.tolist()

    point_items = []
    for point in point_list:
        covered_by = items[items.covers(point)]
        if len(covered_by):
            point_items.append(features_d[covered_by.index[0]])
        else:
            # There weren't any scenes matching our conditions for this point (too cloudy)
            point_items.append(None)

    return labels.assign(stac_item=point_items)

# %%
type(lcn_dgdf)
# Out:
# dask_geopandas.core.GeoDataFrame

# %%
lcn_dgdf
# Out:
# Dask GeoDataFrame Structure:
#                 geometry    name
# npartitions=20
#                 geometry  object
#                      ...     ...
# ...                  ...     ...
#                      ...     ...
#                      ...     ...
# Dask Name: from_pandas, 20 tasks

# %%
def partitioned_geom_extract(labels):
    intersects = shapely.geometry.mapping(labels.unary_union.convex_hull)
    
    # print(intersects)

# %%
# %%time

with ds_client(n_workers=16) as client:
    print(client.dashboard_link)
    df2 = lcn_dgdf.map_partitions(query).compute()
# Out:
# http://127.0.0.1:8787/status
# {'type': 'Polygon', 'coordinates': (((0.0, 0.0), (0.0, 1.0), (1.0, 2.0), (1.0, 1.0), (0.0, 0.0)),)}
# /Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.0-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.0-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.0-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.0-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.0-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.0-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.0-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.0-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.0-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.0-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.0-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.0-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.0-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.0-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.0-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.0-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# distributed.protocol.core - CRITICAL - Failed to deserialize
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.core - ERROR - 0
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/core.py", line 569, in handle_stream
#     msgs = await comm.read()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/tcp.py", line 233, in read
#     msg = await from_frames(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.worker - ERROR - 0
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/worker.py", line 1301, in handle_scheduler
#     await self.handle_stream(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/core.py", line 569, in handle_stream
#     msgs = await comm.read()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/tcp.py", line 233, in read
#     msg = await from_frames(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.protocol.core - CRITICAL - Failed to deserialize
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.protocol.core - CRITICAL - Failed to deserialize
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.core - ERROR - 0
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/core.py", line 569, in handle_stream
#     msgs = await comm.read()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/tcp.py", line 233, in read
#     msg = await from_frames(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.core - ERROR - 0
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/core.py", line 569, in handle_stream
#     msgs = await comm.read()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/tcp.py", line 233, in read
#     msg = await from_frames(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.worker - ERROR - 0
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/worker.py", line 1301, in handle_scheduler
#     await self.handle_stream(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/core.py", line 569, in handle_stream
#     msgs = await comm.read()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/tcp.py", line 233, in read
#     msg = await from_frames(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.worker - ERROR - 0
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/worker.py", line 1301, in handle_scheduler
#     await self.handle_stream(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/core.py", line 569, in handle_stream
#     msgs = await comm.read()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/tcp.py", line 233, in read
#     msg = await from_frames(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.protocol.core - CRITICAL - Failed to deserialize
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.core - ERROR - 0
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/core.py", line 569, in handle_stream
#     msgs = await comm.read()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/tcp.py", line 233, in read
#     msg = await from_frames(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.protocol.core - CRITICAL - Failed to deserialize
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.core - ERROR - 0
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/core.py", line 569, in handle_stream
#     msgs = await comm.read()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/tcp.py", line 233, in read
#     msg = await from_frames(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.worker - ERROR - 0
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/worker.py", line 1301, in handle_scheduler
#     await self.handle_stream(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/core.py", line 569, in handle_stream
#     msgs = await comm.read()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/tcp.py", line 233, in read
#     msg = await from_frames(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.worker - ERROR - 0
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/worker.py", line 1301, in handle_scheduler
#     await self.handle_stream(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/core.py", line 569, in handle_stream
#     msgs = await comm.read()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/tcp.py", line 233, in read
#     msg = await from_frames(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.protocol.core - CRITICAL - Failed to deserialize
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.core - ERROR - 0
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/core.py", line 569, in handle_stream
#     msgs = await comm.read()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/tcp.py", line 233, in read
#     msg = await from_frames(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.protocol.core - CRITICAL - Failed to deserialize
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.core - ERROR - 0
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/core.py", line 569, in handle_stream
#     msgs = await comm.read()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/tcp.py", line 233, in read
#     msg = await from_frames(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.protocol.core - CRITICAL - Failed to deserialize
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.worker - ERROR - 0
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/worker.py", line 1301, in handle_scheduler
#     await self.handle_stream(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/core.py", line 569, in handle_stream
#     msgs = await comm.read()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/tcp.py", line 233, in read
#     msg = await from_frames(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.core - ERROR - 0
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/core.py", line 569, in handle_stream
#     msgs = await comm.read()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/tcp.py", line 233, in read
#     msg = await from_frames(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.worker - ERROR - 0
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/worker.py", line 1301, in handle_scheduler
#     await self.handle_stream(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/core.py", line 569, in handle_stream
#     msgs = await comm.read()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/tcp.py", line 233, in read
#     msg = await from_frames(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.worker - ERROR - 0
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/worker.py", line 1301, in handle_scheduler
#     await self.handle_stream(
# ...
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# (
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# distributed.worker - ERROR - 0
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/worker.py", line 1301, in handle_scheduler
#     await self.handle_stream(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/core.py", line 569, in handle_stream
#     msgs = await comm.read()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/tcp.py", line 233, in read
#     msg = await from_frames(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <tornado.platform.asyncio.AsyncIOLoop object at 0x10bb07100>>, <Task finished name='Task-6' coro=<Worker.handle_scheduler() done, defined at /Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/worker.py:1299> exception=KeyError(0)>)
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/worker.py", line 1301, in handle_scheduler
#     await self.handle_stream(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/core.py", line 569, in handle_stream
#     msgs = await comm.read()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/tcp.py", line 233, in read
#     msg = await from_frames(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <tornado.platform.asyncio.AsyncIOLoop object at 0x10dceb100>>, <Task finished name='Task-6' coro=<Worker.handle_scheduler() done, defined at /Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/worker.py:1299> exception=KeyError(0)>)
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/worker.py", line 1301, in handle_scheduler
#     await self.handle_stream(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/core.py", line 569, in handle_stream
#     msgs = await comm.read()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/tcp.py", line 233, in read
#     msg = await from_frames(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <tornado.platform.asyncio.AsyncIOLoop object at 0x10f7fd100>>, <Task finished name='Task-6' coro=<Worker.handle_scheduler() done, defined at /Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/worker.py:1299> exception=KeyError(0)>)
# Traceback (most recent call last):
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/worker.py", line 1301, in handle_scheduler
#     await self.handle_stream(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/core.py", line 569, in handle_stream
#     msgs = await comm.read()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/tcp.py", line 233, in read
#     msg = await from_frames(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 78, in from_frames
#     res = _from_frames()
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/comm/utils.py", line 61, in _from_frames
#     return protocol.loads(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 111, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/core.py", line 103, in _decode_default
#     return merge_and_deserialize(
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 488, in merge_and_deserialize
#     return deserialize(header, merged_frames, deserializers=deserializers)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 417, in deserialize
#     return loads(header, frames)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/serialize.py", line 96, in pickle_loads
#     return pickle.loads(x, buffers=new)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 75, in loads
#     return pickle.loads(x)
#   File "/Users/kendallsmith/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/geopandas/array.py", line 424, in __setstate__
#     geoms = pygeos.from_wkb(state[0])
# KeyError: 0
# ---------------------------------------------------------------------------
# KilledWorker                              Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/dask/base.py in compute(self, **kwargs)
#     286         dask.base.compute
#     287         """
# --> 288         (result,) = compute(self, traverse=False, **kwargs)
#     289         return result
#     290
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/dask/base.py in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     569         postcomputes.append(x.__dask_postcompute__())
#     570
# --> 571     results = schedule(dsk, keys, **kwargs)
#     572     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     573
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/client.py in get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2689                     should_rejoin = False
#    2690             try:
# -> 2691                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2692             finally:
#    2693                 for f in futures.values():
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/client.py in gather(self, futures, errors, direct, asynchronous)
#    1944             else:
#    1945                 local_worker = None
# -> 1946             return self.sync(
#    1947                 self._gather,
#    1948                 futures,
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/utils.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     308             return future
#     309         else:
# --> 310             return sync(
#     311                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     312             )
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     362     if error[0]:
#     363         typ, exc, tb = error[0]
# --> 364         raise exc.with_traceback(tb)
#     365     else:
#     366         return result[0]
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/utils.py in f()
#     347             if callback_timeout is not None:
#     348                 future = asyncio.wait_for(future, callback_timeout)
# --> 349             result[0] = yield future
#     350         except Exception:
#     351             error[0] = sys.exc_info()
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/tornado/gen.py in run(self)
#     760
#     761                     try:
# --> 762                         value = future.result()
#     763                     except Exception:
#     764                         exc_info = sys.exc_info()
#
# ~/opt/anaconda3/envs/mlhub/lib/python3.9/site-packages/distributed/client.py in _gather(self, futures, errors, direct, local_worker)
#    1809                             exc = CancelledError(key)
#    1810                         else:
# -> 1811                             raise exception.with_traceback(traceback)
#    1812                         raise exc
#    1813                     if errors == "skip":
#
# KilledWorker: ("('from_pandas-374f41ae8f1baa2f218821dc52b86b9a', 12)", <WorkerState 'tcp://127.0.0.1:52221', name: 5, status: closed, memory: 0, processing: 4>)

# %%
shapely.geometry.mapping(lcn_gdf.iloc[0:1].unary_union)
# Out:
# {'type': 'Polygon',
#  'coordinates': (((46.22372650315114, 7.637727360104802),
#    (46.223792488589126, 7.66087904636043),
#    (46.24699893998356, 7.660812489646023),
#    (46.24693170406418, 7.637661006840825),
#    (46.22372650315114, 7.637727360104802)),)}

# %%
search_start, search_end
# Out:
# ('2018-01-01', '2018-12-31')

# %%
mlhub_catalog = ps_client.open(
    url=MLHUB_ROOT_URL,
    parameters={"key": MLHUB_API_KEY}, 
    ignore_conformance=True
)

# %%
# %%time
# The time frame in which we search for non-cloudy imagery
search = mlhub_catalog.search(
    collections=[lcn_source_name],
    intersects=shapely.geometry.mapping(lcn_gdf.iloc[0:1].unary_union),
    datetime=[search_start, search_end],
    query={}, # "eo:cloud_cover": {"lt": 10}
    limit=10,
)
# Out:
# CPU times: user 5.13 ms, sys: 7.46 ms, total: 12.6 ms
# Wall time: 10.8 ms

# %%
# %%time
item_collection = search.get_all_items()
# Out:
# CPU times: user 160 ms, sys: 17.1 ms, total: 177 ms
# Wall time: 3.32 s

# %%
type(item_collection)
# Out:
# pystac.item_collection.ItemCollection

# %%
ic = search.get_all_items_as_dict()

# %%
ic.keys()
# Out:
# dict_keys(['type', 'features'])

# %%
len(ic['features'])
# Out:
# 73

# %%
ic['features'][0]
# Out:
# {'id': 'ref_landcovernet_v1_source_38NPP_05_20181231',
#  'bbox': [46.22372650315114,
#   7.637661006840825,
#   46.24699893998356,
#   7.66087904636043],
#  'type': 'Feature',
#  'links': [{'rel': 'collection',
#    'type': 'application/json',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source'},
#   {'rel': 'parent',
#    'type': 'application/json',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source'},
#   {'rel': 'root',
#    'type': 'application/json',
#    'href': 'http://api.radiant.earth/mlhub/v1/'},
#   {'rel': 'self',
#    'type': 'application/geo+json',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_05_20181231'},
#   {'rel': 'alternate',
#    'type': 'application/json',
#    'title': 'tiles',
#    'href': 'http://api.radiant.earth/mlhub/v1/collections/ref_landcovernet_v1_source/items/ref_landcovernet_v1_source_38NPP_05_20181231/tiles'}],
#  'assets': {'B01': {'href': 'https://api.radiant.earth/mlhub/v1/download/gAAAAABh_CfObAztaYkW6JHrCKVc12_etkOzlcHzF-xUHvUCG3g9NAvEJVRa1aX-r67b3aB7S8hP8KjcBe-IgrosMZuIQRj8gWzPLBKfAbFiI6v7714FH106rQ3s2pkCExYyWMqtnT3NtwYK_4FsF4Kxm6abRYr12gr8OPK_UI6j12aGFLS6jgCsiHpQLblENebKmrUAiCbFCNP0cPbvScs7Q6U3eM7Z_aWqTEGVGB_iJqX1a7gJQz79WQ0KOVp95c8iQKN2rXTPvseVG0_vktPzGSH29UeQyb3klpwV4BquV2aJApeO6A4cQ_Ql2rzPOBWYJOazDn0j',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': '38NPP_05_20181231_

#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': '38NPP_05_20181231_CLD_10m',
#    'eo:bands': [{'name': 'CLD',
#      'common_name': 'Cloud Mask',
#      'description': 'Cloud Mask'}]},
#   'SCL': {'href': 'https://api.radiant.earth/mlhub/v1/download/gAAAAABh_CfOk6jgr85joS00ygUQ8xEYbOXnG8CqLC3px7cLdSd4zXX_OKNbIr_4Jllm6xYYHi34LeQndJrTSAGOYO4ELCK2dPefl0R94SozivGa8imkjvSy4f-_OyUmXbCUdPXJgqhlY0CyEGw_Ku5TVRsKPCXVDr2E9XYVmOfU6X9vo04wbwulzZ1r1n4981oSBzBG3FvMpZL43oXOTJ3DDAs4-KTz0AFUUMc8sXZbiixYdjqHcYWzYKkTfQzmmDAmgTXVNFUAgaEil_EuOpW0y2F4MB3ElLD_sGoQMzC1vjI8K1Ssnla2PxYCP08FYlU6cmJ9zLiF',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': '38NPP_05_20181231_SCL_10m',
#    'eo:bands': [{'name': 'SCL',
#      'common_name': 'Scene Classification Layer',
#      'description': 'Scene Classification Layer'}]}},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[46.22372650315114, 7.637727360104802],
#     [46.223792488589126, 7.66087904636043],
#     [46.24699893998356, 7.660812489646023],
#     [46.24693170406418, 7.637661006840825],
#     [46.22372650315114, 7.637727360104802]]]},
#  'collection': 'ref_landcovernet_v1_source',
#  'properties': {'gsd': 10,
#   'datetime': '2018-12-31T00:00:00Z',
#   'eo:bands': [{'name': 'B01',
#     'common_name': 'Coastal Aerosol',
#     'description': 'Coastal Aerosol'},
#    {'name': 'B02', 'common_name': 'Blue', 'description': 'Blue'},
#    {'name': 'B03', 'common_name': 'Green', 'description': 'Green'},
#    {'name': 'B04', 'common_name': 'Red', 'description': 'Red'},
#    {'name': 'B05',
#     'common_name': 'Vegetation Red Edge',
#     'description': 'Vegetation Red Edge (704.1nm)'},
#    {'name': 'B06',
#     'common_name': 'Vegetation Red Edge',
#     'description': 'Vegetation Red Edge (740.1nm)'},
#    {'name': 'B07',
#     'common_name': 'Vegetation Red Edge',
#     'description': 'Vegetation Red Edge (782.8nm)'},
#    {'name': 'B08', 'common_name': 'NIR', 'description': 'NIR'},
#    {'name': 'B8A', 'common_name': 'Narrow NIR', 'description': 'Narrow NIR'},
#    {'name': 'B09',
#     'common_name': 'Water Vapour',
#     'description': 'Water Vapour'},
#    {'name': 'B10',
#     'common_name': 'SWIR - Cirrus',
#     'description': 'SWIR - Cirrus'},
#    {'name': 'B11', 'common_name': 'SWIR', 'description': 'SWIR (1613.7nm)'},
#    {'name': 'B12', 'common_name': 'SWIR', 'description': 'SWIR (2202.4nm)'},
#    {'name': 'CLD', 'common_name': 'Cloud Mask', 'description': 'Cloud Mask'},
#    {'name': 'SCL',
#     'common_name': 'Scene Classification Layer',
#     'description': 'Scene Classification Layer'}],
#   'platform': 'Sentinel-2',
#   'instruments': ['MSI'],
#   'constellation': 'Sentinel-2'},
#  'stac_version': '1.0.0',
#  'stac_extensions': ['https://stac-extensions.github.io/eo/v1.0.0/schema.json']}
